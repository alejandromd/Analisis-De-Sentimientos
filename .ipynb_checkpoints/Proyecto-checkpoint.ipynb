# %%
import pandas
import numpy
tweets_csv = pandas.read_csv('datos.csv',encoding='utf-8')

# %%
# Número de filas y columnas
print(tweets_csv.shape)
# Out:
# (198666, 6)

# %%
# 10 primeras filas
tweets_csv.head(10)
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1       0  1467814119  Mon Apr 06 22:20:40 PDT 2009  NO_QUERY
# 2       0  1467815753  Mon Apr 06 22:21:04 PDT 2009  NO_QUERY
# 3       0  1467817502  Mon Apr 06 22:21:32 PDT 2009  NO_QUERY
# 4       0  1467819650  Mon Apr 06 22:22:05 PDT 2009  NO_QUERY
# 5       0  1467822522  Mon Apr 06 22:22:49 PDT 2009  NO_QUERY
# 6       0  1467824199  Mon Apr 06 22:23:15 PDT 2009  NO_QUERY
# 7       0  1467833690  Mon Apr 06 22:25:44 PDT 2009  NO_QUERY
# 8       0  1467834001  Mon Apr 06 22:25:49 PDT 2009  NO_QUERY
# 9       0  1467835305  Mon Apr 06 22:26:10 PDT 2009  NO_QUERY
#
#               user                                               text
# 0    scotthamilton  is upset that he can't update his Facebook by ...
# 1        cooliodoc   @angry_barista I baked you a cake but I ated it
# 2  BaptisteTheFool  Meh... Almost Lover is the exception... this t...
# ...

# %%
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gonzalo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Gonzalo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Gonzalo\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# en el pdf pone que la funcion se llame asi
def limpiar_texto(tweet):
                
    # Eliminar menciones, hashtags y URLs
    tweet = re.sub(r'@[A-Za-z0-9]+', '', tweet)  # Eliminar menciones
    tweet = re.sub(r'#', '', tweet)  # Eliminar hashtags
    tweet = re.sub(r'http\S+|www\S+', '', tweet)  # Eliminar URLs
    
    # Eliminar símbolos extraños
    tweet = re.sub(r'\W', ' ', tweet)  # Eliminar caracteres no alfanuméricos
    
     # Convertir a minúsculas
    tweet = tweet.lower()
    
    # Tokenización
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(tweet)
    
    # Eliminar stop words
    stop_words = set(stopwords.words('english'))  # stop word para mensajes en ingles
    tokens = [token for token in tokens if token not in stop_words]
    
    # Lematización (stemming)
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Unir tokens nuevamente en un solo texto
    tweet_cleaned = ' '.join(tokens)
        
    return tweet_cleaned

# %%
# Escribe los valores en un archivo de texto
with open('tweets_message.txt', 'w') as file:
    for value in tweets_csv.iloc[:, -1]:
        file.write(str(value) + '\n') # Escribe los mensajes del csv en un txt
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[6], line 4
#       2 with open('tweets_message.txt', 'w') as file:
#       3     for value in tweets_csv.iloc[:, -1]:
# ----> 4         file.write(str(value) + '\n') # Escribe los mensajes del csv en un txt
#
# File ~\AppData\Local\Programs\Python\Python310\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0103' in position 14: character maps to <undefined>

# %%
# Abre el archivo en modo lectura
with open('tweets_message.txt', 'r') as file:
    # Lee el contenido del archivo
    tweets_txt = file.read()

print(tweets_txt)
# Out:
# is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# @angry_barista I baked you a cake but I ated it
# Meh... Almost Lover is the exception... this track gets me depressed every time.
# @fleurylis I don't either. Its depressing. I don't think I even want to know about the kids in suitcases.
# @Viennah Yay! I'm happy for you with your job! But that also means less time for me and you...
# Where did u move to?  I thought u were already in sd. ?? Hmmm. Random u found me. Glad to hear yer doing well.
# @Starrbby too bad I won't be around I lost my job and can't even pay my phone bill lmao aw shucks
# @ashleyac My donkey is sensitive about such comments. Nevertheless, he'd (and me'd) be glad to see your mug asap. Charger is still awol.
# wonders why someone that u like so much can make you so unhappy in a split seccond . depressed .
# ...

# %%
cleaned_tweets= [] 
with open('tweets_message.txt', 'r') as file:
    for line in file:
        cleaned_tweet = limpiar_texto(line)
        cleaned_tweets.append(cleaned_tweet)
        print(cleaned_tweet)
# Out:
# upset update facebook texting might cry result school today also blah
# _barista baked cake ated
# meh almost lover exception track get depressed every time
# either depressing think even want know kid suitcase
# yay happy job also mean le time
# u move thought u already sd hmmm random u found glad hear yer well
# bad around lost job even pay phone bill lmao aw shuck
# donkey sensitive comment nevertheless glad see mug asap charger still awol
# wonder someone u like much make unhappy split seccond depressed
# sorry babe fam annoys thankfully asleep right muahaha evil laugh
# hmm u really enjoy problem constant u think thing find someone ulike
# emily glad mommy done training new job miss
# damn grind inspirational saddening time want stop cuz like u much love
# haha cooooold still go show incredible stuff
# missing babe long alive happy ya tired love imma try sleep hopefully headstart
# living downtown sure much fun
# send dvd co missed heap happy
# ...

# %%
cleaned_tweets
# Out:
# ['upset update facebook texting might cry result school today also blah',
#  '_barista baked cake ated',
#  'meh almost lover exception track get depressed every time',
#  'either depressing think even want know kid suitcase',
#  'yay happy job also mean le time',
#  'u move thought u already sd hmmm random u found glad hear yer well',
#  'bad around lost job even pay phone bill lmao aw shuck',
#  'donkey sensitive comment nevertheless glad see mug asap charger still awol',
#  'wonder someone u like much make unhappy split seccond depressed',
#  'sorry babe fam annoys thankfully asleep right muahaha evil laugh',
#  'hmm u really enjoy problem constant u think thing find someone ulike',
#  'emily glad mommy done training new job miss',
#  'damn grind inspirational saddening time want stop cuz like u much love',
#  'haha cooooold still go show incredible stuff',
#  'missing babe long alive happy ya tired love imma try sleep hopefully headstart',
#  'living downtown sure much fun',
# ...

# %%
import csv
from textblob import TextBlob

# %%
# con polaridad
classified_tweets = []

for line in cleaned_tweets:
    blob = TextBlob(line)
    polaridad = blob.sentiment.polarity
    
    if polaridad > 0.4:
        label = 'Muy feliz'
        
    elif polaridad > 0:
        label = 'Contento'
    elif polaridad == 0:
        label = 'Neutro'
    elif polaridad > -0.4:
        label = 'Molesto'
    else:
        label = 'Hater'
    
    classified_tweets.append([line, label])

# Guardar los resultados en un archivo CSV
with open('classified_tweets.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['tweet', 'label'])
    writer.writerows(classified_tweets)

# %%
# con valor de las etiquetas, no usa textBlob y quieren q lo usemos asi q asi no es.
# Lo podemos usar para el paso 4, para validar y corregir los datos
# (este es mortal hacerlo de 0 pq habria que poner muchos valores en cada etiqueta, pero el de arriba tiene fallitos aunq en general va bien)
labels = {
    'Muy feliz': ['happy', 'cheerful', 'excited'],
    'Contento': ['glad', 'satisfied', 'pleasant'],
    'Neutro': ['neutral', 'indifferent', 'normal'],
    'Molesto': ['annoying', 'angry', 'cry'],
    'Hater': ['hate', 'negative', 'critical']
}

classified_tweets = []

for line in cleaned_tweets:
    label = 'Neutro' # neutro por defecto
    
    for current_label, valuesOfLabels in labels.items():
        if any(valuesOfLabels in line for valuesOfLabels in valuesOfLabels):
            label = current_label
            break
    
    classified_tweets.append([line, label])

# Guardar los resultados en un archivo CSV
with open('classified_tweets2.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['tweet', 'label'])
    writer.writerows(classified_tweets)

# %% [markdown]
# Función de balanceo de tweets polarizados para tomar 1000 muestras de cada clase

# %%
def generar_muestra_balanceada(archivo_entrada, archivo_salida, num_ejemplos):
    datos = {}
    encabezados = []
    with open(archivo_entrada, 'r') as archivo:
        lector_csv = csv.DictReader(archivo)
        encabezados = lector_csv.fieldnames
        for fila in lector_csv:
            clase = fila['label']
            if clase in datos:
                datos[clase].append(fila)
            else:
                datos[clase] = [fila]

    muestra_balanceada = []
    for clase, ejemplos in datos.items():
        if len(ejemplos) <= num_ejemplos:
            muestra_balanceada.extend(ejemplos)
        else:
            muestra_balanceada.extend(ejemplos[:num_ejemplos])

    with open(archivo_salida, 'w', newline='') as archivo:
        escritor_csv = csv.DictWriter(archivo, fieldnames=encabezados)
        escritor_csv.writeheader()
        escritor_csv.writerows(muestra_balanceada)

    print(f"Se generó el archivo '{archivo_salida}' con una muestra balanceada.")

# Uso del script
archivo_entrada = 'classified_tweets.csv'
archivo_salida = 'balanced_sample.csv'
num_ejemplos = 1000

generar_muestra_balanceada(archivo_entrada, archivo_salida, num_ejemplos)
# Out:
# Se generó el archivo 'balanced_sample.csv' con una muestra balanceada.

# %%
classified_tweets_csv = pandas.read_csv('balanced_sample.csv')
classified_tweets_csv.head(3)
# Out:
#                                                tweet   label
# 0  upset update facebook texting might cry result...  Neutro
# 1                           _barista baked cake ated  Neutro
# 2  meh almost lover exception track get depressed...  Neutro

# %%
import sklearn.preprocessing as preprocessing

atributos = classified_tweets_csv['tweet']  # selección de las columnas de atributos
objetivo = classified_tweets_csv['label']  # selección de la columna objetivo
codificador_objetivo = preprocessing.LabelEncoder()

# %%
objetivo_codificado = codificador_objetivo.fit_transform(objetivo)
print(codificador_objetivo.classes_)
# Out:
# ['Contento' 'Hater' 'Molesto' 'Muy feliz' 'Neutro']

# %%
print(pandas.Series(objetivo).value_counts(normalize=True))
# Out:
# label
# Neutro       0.2
# Hater        0.2
# Contento     0.2
# Molesto      0.2
# Muy feliz    0.2
# Name: proportion, dtype: float64
